# %%
import setup
setup.init()

# %%
from django.contrib.auth import get_user_model

User = get_user_model()

User.objects.all()
# Out:
# <QuerySet [<User: om_patil>, <User: staff>, <User: aditya>, <User: ethon_hunt>]>

# %%
user_obj = User.objects.last()
# user_obj.save()

# %%
from document.models import Document
doc_obj = Document(
    owner=user_obj,
    title="Hellow world"
)
# doc_obj.save()

# %%
Document.objects.create(owner_id=1, title="New title")
# Out:
# <Document: New title>

# %%
new_usr = User.objects.get(username="ethon_hunt")
new_usr.is_staff = True
new_usr.set_password("12345")
new_usr.save()

# %%
# superuser = admin user
# python manage.py createsuperuser
# User.objects.create_superuser()

super_u = User.objects.filter(is_superuser=True).first()
super_u
# Out:
# <User: om_patil>
