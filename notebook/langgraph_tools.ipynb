# %%
import setup
setup.init()

# %%
from ai.tools import list_documents, get_documents

config = {
    "user_id":2
}

# %%
list_documents.invoke(None,config)
# Out:
# {'tags': [], 'metadata': {'user_id': 2}, 'callbacks': None, 'recursion_limit': 25, 'configurable': {'user_id': 2}}
# [{'id': 1, 'title': 'Hellow world'}, {'id': 2, 'title': 'Title'}]
