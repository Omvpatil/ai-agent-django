# %%
import setup
setup.init()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 2
#       1 import setup
# ----> 2 setup.init()
#
# File ~/Desktop/Codes/projects/ai-agent-django/notebook/setup.py:31, in init(verbose)
#      28 os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"
#      29 import django
# ---> 31 django.setup()
#
# File ~/Desktop/Codes/projects/ai-agent-django/.venv/lib/python3.14/site-packages/django/__init__.py:19, in setup(set_prefix)
#      16 from django.urls import set_script_prefix
#      17 from django.utils.log import configure_logging
# ---> 19 configure_logging(settings.LOGGING_CONFIG, settings.LOGGING)
#      20 if set_prefix:
#      21     set_script_prefix(
#      22         "/" if settings.FORCE_SCRIPT_NAME is None else settings.FORCE_SCRIPT_NAME
#      23     )
#
# ...

# %%
from django.contrib.auth import  get_user_model

User = get_user_model()

User.objects.all()
# Out:
# <QuerySet [<User: om_patil>, <User: staff>, <User: aditya>, <User: ethon_hunt>]>

# %%
# superuser permissions
# => python manage.py createsuperuser
# => User.objects.create_superuser()

super_u = User.objects.filter(is_superuser=True).first()
super_u
# Out:
# <User: om_patil>

# %%
# By default django user does not have permission including the superusers
super_u.user_permissions.all()
# Out:
# <QuerySet []>

# %%
from django.contrib.auth.models import Permission
perms_qs = Permission.objects.filter(codename__contains="delete")
for permission in perms_qs:
    print(permission.codename)
# Out:
# delete_logentry
# delete_group
# delete_permission
# delete_user
# delete_contenttype
# delete_document
# delete_session

# %%
staff_u = User.objects.filter(is_superuser=False,is_staff=True).first()
# staff_u.user_permissions.set(perms_qs)
staff_u
# Out:
# <User: ethon_hunt>

# %%
docs_qs = Permission.objects.filter(codename__endswith="document")
docs_qs
# Out:
# <QuerySet [<Permission: Document | document | Can add document>, <Permission: Document | document | Can change document>, <Permission: Document | document | Can delete document>, <Permission: Document | document | Can view document>]>

# %%
new_perms = docs_qs | perms_qs
new_perms
# Out:
# <QuerySet [<Permission: Administration | log entry | Can delete log entry>, <Permission: Authentication and Authorization | group | Can delete group>, <Permission: Authentication and Authorization | permission | Can delete permission>, <Permission: Authentication and Authorization | user | Can delete user>, <Permission: Content Types | content type | Can delete content type>, <Permission: Document | document | Can add document>, <Permission: Document | document | Can change document>, <Permission: Document | document | Can delete document>, <Permission: Document | document | Can view document>, <Permission: Sessions | session | Can delete session>]>

# %%
staff_u.user_permissions.set(new_perms)
